# %%
from transformers import pipeline

# %%
model = pipeline(task="automatic-speech-recognition", model="vasista22/whisper-tamil-medium")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
audio = '/content/cataract_q.wav'

# %%
output = model(audio)
print(output)
# Out:
# {'text': 'கேட்டராக் என்பது என்ன'}

# %%
val = output['text']
print(val)
# Out:
# கேட்டராக் என்பது என்ன

# %%
# !pip install deep_translator

# %%
from deep_translator import GoogleTranslator
to_translate = val
translated = GoogleTranslator(source='auto', target='en').translate(to_translate)
print(translated)
# Out:
# What is Cataract?

# %%
# !pip install tensorflow

# %%
# !pip install langchain
# !pip install faiss-cpu
# !pip install -q sentence_transformers
# !pip install openai
# !pip install tiktoken
# !pip install unstructured[local-inference] -q
# !pip install pdf2image -q
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.16.0 which is incompatible.

# %%
# !pip install torch

# %%
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings, OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains.question_answering import load_qa_chain
from langchain import HuggingFaceHub
from langchain.llms import OpenAI
from llama_index.llms.huggingface import HuggingFaceLLM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-59-b3fc7bbac85a> in <cell line: 8>()
#       6 from langchain import HuggingFaceHub
#       7 from langchain.llms import OpenAI
# ----> 8 from llama_index.llms.huggingface import HuggingFaceLLM
#       9
#
# ModuleNotFoundError: No module named 'llama_index'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install llama_index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 40.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 73.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 89.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.0 MB/s eta 0:00:00
# ...

# %%
loader = UnstructuredPDFLoader("/content/merged_files.pdf")

# %%
document = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1200, chunk_overlap=500)
chunks = text_splitter.split_documents(document)

# %%
chunks[0]
# Out:
# Document(page_content='CATARACT\n\nWhat is the Cataract surgery? Cataract surgery, which is also called lens replacement surgery, is the removal of the natural lens of the h uman eye that has developed a cataract, an opaque or cloudy area. The eye’s natural lens is usually repl aced with an artificial intraocular lens.\n\nCataract types include: * Cataracts affecting the centre of the lens, called nuclear cataract * Cataracts that affect the edges of the lens, called cortical cataract * Cataracts that affect the back of the lens, called posterior sub capsular cataract * Cataracts in new born baby, called congenital cataract\n\nWhat tests do I need before cataract surgery?\n\nA full ocular examination. * Vision and refraction * Slit lamp examination * Corneal topography. * Specular microscopy * DBR (digital biometry reading) * Blood pressure measurements. * High-risk patient (Heart disease) cardiology opinion * Blood sugar measurements in diabetic patients. * General fitness for befor
# ...

# %%
import os
#os.environ["OPENAI_API_KEY"] = "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"
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
# !pip install transformers

# %%
embedding = HuggingFaceEmbeddings()
#embedding = OpenAIEmbeddings()
db = FAISS.from_documents(chunks, embedding)

# %%
llm=HuggingFaceHub(
    repo_id="google/gemma-7b",
    model_kwargs={"temperature":0.1, "max_length":100},
 )

chain = load_qa_chain(llm, chain_type="stuff")
docs2 = db.similarity_search(translated)
output_mssg = chain.run(input_documents=docs2, question=translated)
print(output_mssg)
# Out:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.
#
# CATARACT
#
# What is the Cataract surgery? Cataract surgery, which is also called lens replacement surgery, is the removal of the natural lens of the h uman eye that has developed a cataract, an opaque or cloudy area. The eye’s natural lens is usually repl aced with an artificial intraocular lens.
#
# Cataract types include: * Cataracts affecting the centre of the lens, called nuclear cataract * Cataracts that affect the edges of the lens, called cortical cataract * Cataracts that affect the back of the lens, called posterior sub capsular cataract * Cataracts in new born baby, called congenital cataract
#
# What tests do I need before cataract surgery?
#
# ...

# %%
translated_output = GoogleTranslator(source='auto', target='ta').translate(output_mssg)
print(translated_output)
# Out:
# முடிவில் உள்ள கேள்விக்கு பதிலளிக்க பின்வரும் சூழல் பகுதிகளைப் பயன்படுத்தவும். உங்களுக்கு பதில் தெரியவில்லை என்றால், உங்களுக்குத் தெரியாது என்று சொல்லுங்கள், பதிலை உருவாக்க முயற்சிக்காதீர்கள்.
#
# கண்புரை
#
# கண்புரை அறுவை சிகிச்சை என்றால் என்ன? கண்புரை அறுவை சிகிச்சை, இது லென்ஸ் மாற்று அறுவை சிகிச்சை என்றும் அழைக்கப்படுகிறது, இது கண்புரை, ஒரு ஒளிபுகா அல்லது மேகமூட்டமான பகுதியை உருவாக்கியுள்ள h uman கண்ணின் இயற்கையான லென்ஸை அகற்றுவதாகும். கண்ணின் இயற்கையான லென்ஸ் பொதுவாக செயற்கை உள்விழி லென்ஸால் மாற்றப்படுகிறது.
#
# மாகுலர் இஸ்கெமியா, இது குணப்படுத்த முடியாத மற்றும் நிரந்தரமான மீளமுடியாத மையக் காட்சி இழப்பை ஏற்படுத்தும்.
#
# யாருக்கு கண்புரை அறுவை சிகிச்சை செய்ய முடியாது? பிரிக்கப்பட்ட விழித்திரை வேண்டும். தொற்று போன்ற கண்களின் மருத்துவ நிலை உள்ளது. மேம்பட்ட நீரிழிவு உங்கள் விழித்திரையை பாதித்துள்ளது. கார்னியல் ஓபாசிஃபிகேஷன், அல்சரேஷன் அல்லது வேறு ஏதேனும் சி ஆர்னியல் நோய் போன்ற கார்னியல் நோய்கள் உள்ளன.
#
# ...

# %%
# !pip install gtts

# %%
import gtts as gt

# %%
tts = gt.gTTS(text=translated_output,lang="ta")
tts.save("chatbot_output.wav")

# %%
from IPython.display import Audio, display

sound_file = "/content/chatbot_output.wav"
display(Audio(sound_file, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Keys: </BR>
# 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   </br>
# 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
